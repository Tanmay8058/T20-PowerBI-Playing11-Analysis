# %% [markdown]
# ### Importing modules

# %%
import pandas as pd
import json

# %% [markdown]
# ###  Opening match details json file

# %%
with open ('t20_json_files//t20_wc_match_results.json') as f:
    data = json.load(f)

# %%
df = pd.DataFrame(data[0]['matchSummary'])

# %%
df.head()
# Out:
#          team1        team2       winner     margin   ground     matchDate  \
# 0      Namibia    Sri Lanka      Namibia    55 runs  Geelong  Oct 16, 2022
# 1  Netherlands       U.A.E.  Netherlands  3 wickets  Geelong  Oct 16, 2022
# 2     Scotland  West Indies     Scotland    42 runs   Hobart  Oct 17, 2022
# 3      Ireland     Zimbabwe     Zimbabwe    31 runs   Hobart  Oct 17, 2022
# 4      Namibia  Netherlands  Netherlands  5 wickets  Geelong  Oct 18, 2022
#
#      scorecard
# 0  T20I # 1823
# 1  T20I # 1825
# 2  T20I # 1826
# 3  T20I # 1828
# 4  T20I # 1830

# %%
match_summary = df.rename(columns={"scorecard": "match_code"})

# %%
match_summary.to_csv('csv_files//match_summary.csv')

# %% [markdown]
# ### Creating dictionary which correlates match_code and team names

# %%
match_id_dicts = {}
for index, row in match_summary.iterrows():
    key1 = row['team1'] + ' Vs ' + row['team2']
    key2 = row['team2'] + ' Vs ' + row['team1']
    match_id_dicts[key1] = row['match_code']
    match_id_dicts[key2] = row['match_code']

# %%
match_id_dicts
# Out:
# {'Namibia Vs Sri Lanka': 'T20I # 1823',
#  'Sri Lanka Vs Namibia': 'T20I # 1823',
#  'Netherlands Vs U.A.E.': 'T20I # 1825',
#  'U.A.E. Vs Netherlands': 'T20I # 1825',
#  'Scotland Vs West Indies': 'T20I # 1826',
#  'West Indies Vs Scotland': 'T20I # 1826',
#  'Ireland Vs Zimbabwe': 'T20I # 1828',
#  'Zimbabwe Vs Ireland': 'T20I # 1828',
#  'Namibia Vs Netherlands': 'T20I # 1830',
#  'Netherlands Vs Namibia': 'T20I # 1830',
#  'Sri Lanka Vs U.A.E.': 'T20I # 1832',
#  'U.A.E. Vs Sri Lanka': 'T20I # 1832',
#  'Ireland Vs Scotland': 'T20I # 1833',
#  'Scotland Vs Ireland': 'T20I # 1833',
#  'West Indies Vs Zimbabwe': 'T20I # 1834',
#  'Zimbabwe Vs West Indies': 'T20I # 1834',
#  'Netherlands Vs Sri Lanka': 'T20I # 1835',
#  'Sri Lanka Vs Netherlands': 'T20I # 1835',
#  'Namibia Vs U.A.E.': 'T20I # 1836',
#  'U.A.E. Vs Namibia': 'T20I # 1836',
#  'Ireland Vs West Indies': 'T20I # 1837',
#  'West Indies Vs Ireland': 'T20I # 1837',
#  'Scotland Vs Zimbabwe': 'T20I # 1838',
#  'Zimbabwe Vs Scotland': 'T20I # 1838',
#  'Australia Vs New Zealand': 'T20I # 1839',
#  'New Zealand Vs Australia': 'T20I # 1839',
#  'Afghanistan Vs England': 'T20I # 1840',
#  'England Vs Afghanistan': 'T20I # 1840',
#  'Ireland Vs Sri Lanka': 'T20I # 1841',
#  'Sri Lanka Vs Ireland': 'T20I # 1841',
#  'India Vs Pakistan': 'T20I # 1842',
#  'Pakistan Vs India': 'T20I # 1842',
#  'Bangladesh Vs Netherlands': 'T20I # 1843',
#  'Netherlands Vs Bangladesh': 'T20I # 1843',
#  'South Africa Vs Zimbabwe': 'T20I # 1844',
#  'Zimbabwe Vs South Africa': 'T20I # 1844',
#  'Australia Vs Sri Lanka': 'T20I # 1845',
#  'Sri Lanka Vs Australia': 'T20I # 1845',
#  'England Vs Ireland': 'T20I # 1846',
#  'Ireland Vs England': 'T20I # 1846',
#  'Afghanistan Vs New Zealand': 'T20I # 1846a',
#  'New Zealand Vs Afghanistan': 'T20I # 1846a',
#  'Bangladesh Vs South Africa': 'T20I # 1847',
#  'South Africa Vs Bangladesh': 'T20I # 1847',
#  'India Vs Netherlands': 'T20I # 1848',
#  'Netherlands Vs India': 'T20I # 1848',
#  'Pakistan Vs Zimbabwe': 'T20I # 1849',
#  'Zimbabwe Vs Pakistan': 'T20I # 1849',
#  'Afghanistan Vs Ireland': 'T20I # 1849a',
#  'Ireland Vs Afghanistan': 'T20I # 1849a',
#  'Australia Vs England': 'T20I # 1849b',
#  'England Vs Australia': 'T20I # 1849b',
#  'New Zealand Vs Sri Lanka': 'T20I # 1850',
#  'Sri Lanka Vs New Zealand': 'T20I # 1850',
#  'Bangladesh Vs Zimbabwe': 'T20I # 1851',
#  'Zimbabwe Vs Bangladesh': 'T20I # 1851',
#  'Netherlands Vs Pakistan': 'T20I # 1852',
#  'Pakistan Vs Netherlands': 'T20I # 1852',
#  'India Vs South Africa': 'T20I # 1853',
#  'South Africa Vs India': 'T20I # 1853',
#  'Australia Vs Ireland': 'T20I # 1855',
#  'Ireland Vs Australia': 'T20I # 1855',
#  'Afghanistan Vs Sri Lanka': 'T20I # 1856',
#  'Sri Lanka Vs Afghanistan': 'T20I # 1856',
#  'England Vs New Zealand': 'T20I # 1858',
#  'New Zealand Vs England': 'T20I # 1858',
#  'Netherlands Vs Zimbabwe': 'T20I # 1859',
#  'Zimbabwe Vs Netherlands': 'T20I # 1859',
#  'Bangladesh Vs India': 'T20I # 1860',
#  'India Vs Bangladesh': 'T20I # 1860',
#  'Pakistan Vs South Africa': 'T20I # 1861',
#  'South Africa Vs Pakistan': 'T20I # 1861',
#  'Ireland Vs New Zealand': 'T20I # 1862',
#  'New Zealand Vs Ireland': 'T20I # 1862',
#  'Australia Vs Afghanistan': 'T20I # 1864',
#  'Afghanistan Vs Australia': 'T20I # 1864',
#  'England Vs Sri Lanka': 'T20I # 1867',
#  'Sri Lanka Vs England': 'T20I # 1867',
#  'Netherlands Vs South Africa': 'T20I # 1871',
#  'South Africa Vs Netherlands': 'T20I # 1871',
#  'Bangladesh Vs Pakistan': 'T20I # 1872',
#  'Pakistan Vs Bangladesh': 'T20I # 1872',
#  'India Vs Zimbabwe': 'T20I # 1873',
#  'Zimbabwe Vs India': 'T20I # 1873',
#  'New Zealand Vs Pakistan': 'T20I # 1877',
#  'Pakistan Vs New Zealand': 'T20I # 1877',
#  'England Vs India': 'T20I # 1878',
#  'India Vs England': 'T20I # 1878',
#  'England Vs Pakistan': 'T20I # 1879',
#  'Pakistan Vs England': 'T20I # 1879'}

# %% [markdown]
# ### Opening player info json file

# %%
with open('t20_json_files//t20_wc_player_info.json') as f:
    data = json.load(f)

# %%
player_info = pd.DataFrame(data)

# %%
player_info.head()
# Out:
#                      name     team    battingStyle  \
# 0      Michael van Lingen  Namibia   Left hand Bat
# 1           Divan la Cock  Namibia  Right hand Bat
# 2  Jan Nicol Loftie-Eaton  Namibia   Left hand Bat
# 3           Stephan Baard  Namibia  Right hand Bat
# 4      Gerhard Erasmus(c)  Namibia  Right hand Bat
#
#                  bowlingStyle         playingRole description
# 0             Left arm Medium  Bowling Allrounder
# 1                    Legbreak      Opening Batter
# 2  Right arm Medium, Legbreak              Batter
# 3       Right arm Medium fast              Batter
# 4          Right arm Offbreak          Allrounder

# %%
player_info.name.unique()
# Out:
# array(['Michael van Lingen', 'Divan la Cock', 'Jan Nicol Loftie-Eaton',
#        'Stephan Baard', 'Gerhard Erasmus(c)', 'Jan Frylinck',
#        'David Wiese', 'JJ Smit', 'Pathum Nissanka', 'Kusal Mendisâ€\xa0',
#        'Dhananjaya de Silva', 'Danushka Gunathilaka', 'Bhanuka Rajapaksa',
#        'Dasun Shanaka(c)', 'Wanindu Hasaranga de Silva',
#        'Chamika Karunaratne', 'Pramod Madushan', 'Dushmantha Chameera',
#        'Maheesh Theekshana', 'Gerhard Erasmus', 'Bernard Scholtz',
#        'Ben Shikongo', 'Charith Asalanka', 'David Warner',
#        'Aaron Finch(c)', 'Mitchell Marsh', 'Glenn Maxwell',
#        'Marcus Stoinis', 'Josh Hazlewood', 'Pat Cummins',
#        'Mitchell Starc', 'Ashton Agar', 'Binura Fernando',
#        'Lahiru Kumara', 'Dasun Shanaka', 'Regis Chakabvaâ€\xa0',
#        'Craig Ervine(c)', 'Wessly Madhevere', 'Sean Williams',
#        'Sikandar Raza', 'Milton Shumba', 'Ryan Burl', 'Luke Jongwe',
#        'Paul Stirling', 'Andy Balbirnie(c)', 'Lorcan Tuckerâ€\xa0',
#        'Harry Tector', 'Curtis Campher', 'George Dockrell',
#        'Gareth Delany', 'Mark Adair', 'Simi Singh', 'Barry McCarthy',
#        'Josh Little', 'Richard Ngarava', 'Tendai Chatara',
#        'Blessing Muzarabani', 'Hazratullah Zazai',
#        'Rahmanullah Gurbazâ€\xa0', 'Ibrahim Zadran', 'Usman Ghani',
#        'Najibullah Zadran', 'Mohammad Nabi(c)', 'Azmatullah Omarzai',
#        'Rashid Khan', 'Mujeeb Ur Rahman', 'Fareed Ahmad',
#        'Fazalhaq Farooqi', 'Jos Buttler(c)â€\xa0', 'Alex Hales',
#        'Dawid Malan', 'Ben Stokes', 'Liam Livingstone', 'Harry Brook',
#        'Moeen Ali', 'Chris Woakes', 'Mark Wood', 'Sam Curran',
#        'Adil Rashid', 'Mohammad Nabi', 'Muhammad Waseem',
#        'Vriitya Aravindâ€\xa0', 'Chundangapoyil Rizwan(c)',
#        'Alishan Sharafu', 'Basil Hameed', 'Zane Greenâ€\xa0',
#        'Ruben Trumpelmann', 'Junaid Siddique', 'Zahoor Khan',
#        'Ahmed Raza', 'Karthik Meiyappan', 'Aayan Afzal Khan',
#        'Chirag Suri', 'Kashif Daud', 'Zawar Farid', 'Vikramjit Singh',
#        "Max O'Dowd", 'Bas de Leede', 'Colin Ackermann', 'Tom Cooper',
#        'Scott Edwards(c)â€\xa0', 'Roelof van der Merwe', 'Tim Pringle',
#        'Logan van Beek', 'Fred Klaassen', 'Paul van Meekeren',
#        'Kyle Mayers', 'Johnson Charles', 'Evin Lewis', 'Brandon King',
#        'Nicholas Pooran(c)â€\xa0', 'Rovman Powell', 'Odean Smith',
#        'Obed McCoy', 'Akeal Hosein', 'Alzarri Joseph', 'Jason Holder',
#        'Mohammad Rizwanâ€\xa0', 'Babar Azam(c)', 'Shan Masood',
#        'Iftikhar Ahmed', 'Shadab Khan', 'Haider Ali', 'Mohammad Nawaz',
#        'Asif Ali', 'Shaheen Shah Afridi', 'Haris Rauf', 'KL Rahul',
#        'Rohit Sharma(c)', 'Virat Kohli', 'Suryakumar Yadav', 'Axar Patel',
#        'Hardik Pandya', 'Dinesh Karthikâ€\xa0', 'Ravichandran Ashwin',
#        'Bhuvneshwar Kumar', 'Arshdeep Singh', 'Mohammed Shami',
#        'Naseem Shah', 'Najmul Hossain Shanto', 'Soumya Sarkar',
#        'Litton Das', 'Shakib Al Hasan(c)', 'Afif Hossain', 'Yasir Ali',
#        'Nurul Hasanâ€\xa0', 'Mosaddek Hossain', 'Taskin Ahmed',
#        'Hasan Mahmud', 'Shariz Ahmad', 'Shakib Al Hasan',
#        'Mustafizur Rahman', 'Fionn Hand', 'George Munsey',
#        'Michael Jones', 'Matthew Crossâ€\xa0', 'Richie Berrington(c)',
#        'Calum MacLeod', 'Michael Leask', 'Chris Greaves',
#        'Shamarh Brooks', 'Mark Watt', 'Brad Wheal', 'Josh Davey',
#        'Safyaan Sharif', 'Quinton de Kockâ€\xa0', 'Temba Bavuma(c)',
#        'Kagiso Rabada', 'Wayne Parnell', 'Lungi Ngidi', 'Keshav Maharaj',
#        'Anrich Nortje', 'Timm van der Gugten', 'Finn Allen',
#        'Devon Conwayâ€\xa0', 'Kane Williamson(c)', 'Glenn Phillips',
#        'James Neesham', 'Tim David', 'Matthew Wadeâ€\xa0', 'Adam Zampa',
#        'Trent Boult', 'Tim Southee', 'Mitchell Santner',
#        'Lockie Ferguson', 'Ish Sodhi', 'Aryan Lakra', 'Stephan Myburgh',
#        'Brandon Glover', 'Shoriful Islam', 'Daryl Mitchell',
#        'Kasun Rajitha', 'Deepak Hooda', 'Rilee Rossouw', 'Aiden Markram',
#        'David Miller', 'Tristan Stubbs', 'Nasum Ahmed', 'Mohammad Haris',
#        'Mohammad Wasim', 'Ebadot Hossain', 'Heinrich Klaasen',
#        'Brad Evans', 'Fakhar Zaman', 'Cameron Green', 'Steven Smith',
#        'Matthew Wade(c)â€\xa0', 'Kane Richardson', 'Gulbadin Naib',
#        'Darwish Rasooli', 'Naveen-ul-Haq', 'Rishabh Pantâ€\xa0',
#        'Tony Munyonga', 'Wellington Masakadza', 'Tabraiz Shamsi',
#        'Phil Salt', 'Chris Jordan', 'Regis Chakabva(c)â€\xa0',
#        'Mehidy Hasan Miraz'], dtype=object)

# %% [markdown]
# #### We see that there are some non alphabatical characters in some names and we need to remove/replace them

# %%
player_info['name'] = player_info['name'].apply(lambda x : x.replace("â€\xa0",""))

# %%
player_info.name.unique()
# Out:
# array(['Michael van Lingen', 'Divan la Cock', 'Jan Nicol Loftie-Eaton',
#        'Stephan Baard', 'Gerhard Erasmus(c)', 'Jan Frylinck',
#        'David Wiese', 'JJ Smit', 'Pathum Nissanka', 'Kusal Mendis',
#        'Dhananjaya de Silva', 'Danushka Gunathilaka', 'Bhanuka Rajapaksa',
#        'Dasun Shanaka(c)', 'Wanindu Hasaranga de Silva',
#        'Chamika Karunaratne', 'Pramod Madushan', 'Dushmantha Chameera',
#        'Maheesh Theekshana', 'Gerhard Erasmus', 'Bernard Scholtz',
#        'Ben Shikongo', 'Charith Asalanka', 'David Warner',
#        'Aaron Finch(c)', 'Mitchell Marsh', 'Glenn Maxwell',
#        'Marcus Stoinis', 'Josh Hazlewood', 'Pat Cummins',
#        'Mitchell Starc', 'Ashton Agar', 'Binura Fernando',
#        'Lahiru Kumara', 'Dasun Shanaka', 'Regis Chakabva',
#        'Craig Ervine(c)', 'Wessly Madhevere', 'Sean Williams',
#        'Sikandar Raza', 'Milton Shumba', 'Ryan Burl', 'Luke Jongwe',
#        'Paul Stirling', 'Andy Balbirnie(c)', 'Lorcan Tucker',
#        'Harry Tector', 'Curtis Campher', 'George Dockrell',
#        'Gareth Delany', 'Mark Adair', 'Simi Singh', 'Barry McCarthy',
#        'Josh Little', 'Richard Ngarava', 'Tendai Chatara',
#        'Blessing Muzarabani', 'Hazratullah Zazai', 'Rahmanullah Gurbaz',
#        'Ibrahim Zadran', 'Usman Ghani', 'Najibullah Zadran',
#        'Mohammad Nabi(c)', 'Azmatullah Omarzai', 'Rashid Khan',
#        'Mujeeb Ur Rahman', 'Fareed Ahmad', 'Fazalhaq Farooqi',
#        'Jos Buttler(c)', 'Alex Hales', 'Dawid Malan', 'Ben Stokes',
#        'Liam Livingstone', 'Harry Brook', 'Moeen Ali', 'Chris Woakes',
#        'Mark Wood', 'Sam Curran', 'Adil Rashid', 'Mohammad Nabi',
#        'Muhammad Waseem', 'Vriitya Aravind', 'Chundangapoyil Rizwan(c)',
#        'Alishan Sharafu', 'Basil Hameed', 'Zane Green',
#        'Ruben Trumpelmann', 'Junaid Siddique', 'Zahoor Khan',
#        'Ahmed Raza', 'Karthik Meiyappan', 'Aayan Afzal Khan',
#        'Chirag Suri', 'Kashif Daud', 'Zawar Farid', 'Vikramjit Singh',
#        "Max O'Dowd", 'Bas de Leede', 'Colin Ackermann', 'Tom Cooper',
#        'Scott Edwards(c)', 'Roelof van der Merwe', 'Tim Pringle',
#        'Logan van Beek', 'Fred Klaassen', 'Paul van Meekeren',
#        'Kyle Mayers', 'Johnson Charles', 'Evin Lewis', 'Brandon King',
#        'Nicholas Pooran(c)', 'Rovman Powell', 'Odean Smith', 'Obed McCoy',
#        'Akeal Hosein', 'Alzarri Joseph', 'Jason Holder',
#        'Mohammad Rizwan', 'Babar Azam(c)', 'Shan Masood',
#        'Iftikhar Ahmed', 'Shadab Khan', 'Haider Ali', 'Mohammad Nawaz',
#        'Asif Ali', 'Shaheen Shah Afridi', 'Haris Rauf', 'KL Rahul',
#        'Rohit Sharma(c)', 'Virat Kohli', 'Suryakumar Yadav', 'Axar Patel',
#        'Hardik Pandya', 'Dinesh Karthik', 'Ravichandran Ashwin',
#        'Bhuvneshwar Kumar', 'Arshdeep Singh', 'Mohammed Shami',
#        'Naseem Shah', 'Najmul Hossain Shanto', 'Soumya Sarkar',
#        'Litton Das', 'Shakib Al Hasan(c)', 'Afif Hossain', 'Yasir Ali',
#        'Nurul Hasan', 'Mosaddek Hossain', 'Taskin Ahmed', 'Hasan Mahmud',
#        'Shariz Ahmad', 'Shakib Al Hasan', 'Mustafizur Rahman',
#        'Fionn Hand', 'George Munsey', 'Michael Jones', 'Matthew Cross',
#        'Richie Berrington(c)', 'Calum MacLeod', 'Michael Leask',
#        'Chris Greaves', 'Shamarh Brooks', 'Mark Watt', 'Brad Wheal',
#        'Josh Davey', 'Safyaan Sharif', 'Quinton de Kock',
#        'Temba Bavuma(c)', 'Kagiso Rabada', 'Wayne Parnell', 'Lungi Ngidi',
#        'Keshav Maharaj', 'Anrich Nortje', 'Timm van der Gugten',
#        'Finn Allen', 'Devon Conway', 'Kane Williamson(c)',
#        'Glenn Phillips', 'James Neesham', 'Tim David', 'Matthew Wade',
#        'Adam Zampa', 'Trent Boult', 'Tim Southee', 'Mitchell Santner',
#        'Lockie Ferguson', 'Ish Sodhi', 'Aryan Lakra', 'Stephan Myburgh',
#        'Brandon Glover', 'Shoriful Islam', 'Daryl Mitchell',
#        'Kasun Rajitha', 'Deepak Hooda', 'Rilee Rossouw', 'Aiden Markram',
#        'David Miller', 'Tristan Stubbs', 'Nasum Ahmed', 'Mohammad Haris',
#        'Mohammad Wasim', 'Ebadot Hossain', 'Heinrich Klaasen',
#        'Brad Evans', 'Fakhar Zaman', 'Cameron Green', 'Steven Smith',
#        'Matthew Wade(c)', 'Kane Richardson', 'Gulbadin Naib',
#        'Darwish Rasooli', 'Naveen-ul-Haq', 'Rishabh Pant',
#        'Tony Munyonga', 'Wellington Masakadza', 'Tabraiz Shamsi',
#        'Phil Salt', 'Chris Jordan', 'Regis Chakabva(c)',
#        'Mehidy Hasan Miraz'], dtype=object)

# %%
player_info.to_csv('csv_files//player_info.csv')

# %% [markdown]
# ### Opening batting details json file

# %%
with open('t20_json_files//t20_wc_batting_summary.json') as f:
    data = json.load(f)

# %%
arr = []

# %%
for i in range(len(data)):
    for j in range(len(data[i]['battingSummary'])):
        arr.append(data[i]['battingSummary'][j])

# %%
batting_summary = pd.DataFrame(arr)

# %%
batting_summary.head()
# Out:
#                   match teamInnings  battingPos             batsmanName  \
# 0  Namibia Vs Sri Lanka     Namibia           1      Michael van Lingen
# 1  Namibia Vs Sri Lanka     Namibia           2           Divan la Cock
# 2  Namibia Vs Sri Lanka     Namibia           3  Jan Nicol Loftie-Eaton
# 3  Namibia Vs Sri Lanka     Namibia           4           Stephan Baard
# 4  Namibia Vs Sri Lanka     Namibia           5      Gerhard Erasmus(c)
#
#                          dismissal runs balls 4s 6s      SR
# 0     c Pramod Madushan b Chameera    3     6  0  0   50.00
# 1      c Shanaka b Pramod Madushan    9     9  1  0  100.00
# 2        c â€ Mendis b Karunaratne   20    12  1  2  166.66
# 3  c DM de Silva b Pramod Madushan   26    24  2  0  108.33
# 4     c Gunathilaka b PWH de Silva   20    24  0  0   83.33

# %% [markdown]
# ### Creating new column which would tell out : if dismissal have some string and not out if not

# %%
batting_summary['out/notout'] = batting_summary['dismissal'].apply(lambda x : "out" if len(x) > 0 else "notout")

# %%
batting_summary.drop(['dismissal'],axis=1,inplace = True)

# %%
batting_summary['batsmanName'].unique()
# Out:
# array(['Michael van Lingen', 'Divan la Cock', 'Jan Nicol Loftie-Eaton',
#        'Stephan Baard', 'Gerhard Erasmus(c)', 'Jan Frylinck',
#        'David Wiese', 'JJ Smit', 'Pathum Nissanka', 'Kusal Mendisâ€\xa0',
#        'Dhananjaya de Silva', 'Danushka Gunathilaka', 'Bhanuka Rajapaksa',
#        'Dasun Shanaka(c)', 'Wanindu Hasaranga de Silva',
#        'Chamika Karunaratne', 'Pramod Madushan', 'Dushmantha Chameera',
#        'Maheesh Theekshana', 'Chirag Suri', 'Muhammad Waseem',
#        'Kashif Daud', 'Vriitya Aravindâ€\xa0', 'Zawar Farid',
#        'Basil Hameed', 'Chundangapoyil Rizwan(c)', 'Aayan Afzal Khan',
#        'Karthik Meiyappan', 'Junaid Siddique', 'Vikramjit Singh',
#        "Max O'Dowd", 'Bas de Leede', 'Colin Ackermann', 'Tom Cooper',
#        'Scott Edwards(c)â€\xa0', 'Roelof van der Merwe', 'Tim Pringle',
#        'Logan van Beek', 'George Munsey', 'Michael Jones',
#        'Matthew Crossâ€\xa0', 'Richie Berrington(c)', 'Calum MacLeod',
#        'Michael Leask', 'Chris Greaves', 'Kyle Mayers', 'Evin Lewis',
#        'Brandon King', 'Nicholas Pooran(c)â€\xa0', 'Shamarh Brooks',
#        'Rovman Powell', 'Jason Holder', 'Akeal Hosein', 'Alzarri Joseph',
#        'Odean Smith', 'Obed McCoy', 'Regis Chakabvaâ€\xa0',
#        'Craig Ervine(c)', 'Wessly Madhevere', 'Sean Williams',
#        'Sikandar Raza', 'Milton Shumba', 'Ryan Burl', 'Luke Jongwe',
#        'Paul Stirling', 'Andy Balbirnie(c)', 'Lorcan Tuckerâ€\xa0',
#        'Harry Tector', 'Curtis Campher', 'George Dockrell',
#        'Gareth Delany', 'Mark Adair', 'Simi Singh', 'Barry McCarthy',
#        'Josh Little', 'Charith Asalanka', 'Aryan Lakra', 'Zahoor Khan',
#        'Johnson Charles', 'Regis Chakabva(c)â€\xa0', 'Tony Munyonga',
#        'Richard Ngarava', 'Tendai Chatara', 'Blessing Muzarabani',
#        'Timm van der Gugten', 'Fred Klaassen', 'Paul van Meekeren',
#        'Alishan Sharafu', 'Zane Greenâ€\xa0', 'Ruben Trumpelmann',
#        'Bernard Scholtz', 'Josh Davey', 'Finn Allen',
#        'Devon Conwayâ€\xa0', 'Kane Williamson(c)', 'Glenn Phillips',
#        'James Neesham', 'David Warner', 'Aaron Finch(c)',
#        'Mitchell Marsh', 'Glenn Maxwell', 'Marcus Stoinis', 'Tim David',
#        'Matthew Wadeâ€\xa0', 'Pat Cummins', 'Mitchell Starc',
#        'Adam Zampa', 'Josh Hazlewood', 'Hazratullah Zazai',
#        'Rahmanullah Gurbazâ€\xa0', 'Ibrahim Zadran', 'Usman Ghani',
#        'Najibullah Zadran', 'Mohammad Nabi(c)', 'Azmatullah Omarzai',
#        'Rashid Khan', 'Mujeeb Ur Rahman', 'Fareed Ahmad',
#        'Fazalhaq Farooqi', 'Jos Buttler(c)â€\xa0', 'Alex Hales',
#        'Dawid Malan', 'Ben Stokes', 'Liam Livingstone', 'Harry Brook',
#        'Moeen Ali', 'Mohammad Rizwanâ€\xa0', 'Babar Azam(c)',
#        'Shan Masood', 'Iftikhar Ahmed', 'Shadab Khan', 'Haider Ali',
#        'Mohammad Nawaz', 'Asif Ali', 'Shaheen Shah Afridi', 'Haris Rauf',
#        'KL Rahul', 'Rohit Sharma(c)', 'Virat Kohli', 'Suryakumar Yadav',
#        'Axar Patel', 'Hardik Pandya', 'Dinesh Karthikâ€\xa0',
#        'Ravichandran Ashwin', 'Najmul Hossain Shanto', 'Soumya Sarkar',
#        'Litton Das', 'Shakib Al Hasan(c)', 'Afif Hossain', 'Yasir Ali',
#        'Nurul Hasanâ€\xa0', 'Mosaddek Hossain', 'Taskin Ahmed',
#        'Hasan Mahmud', 'Shariz Ahmad', 'Quinton de Kockâ€\xa0',
#        'Temba Bavuma(c)', 'Fionn Hand', 'Rilee Rossouw', 'Tristan Stubbs',
#        'Aiden Markram', 'David Miller', 'Wayne Parnell',
#        'Mehidy Hasan Miraz', 'Mustafizur Rahman', 'Brad Evans',
#        'Mohammad Wasim', 'Daryl Mitchell', 'Mitchell Santner',
#        'Ish Sodhi', 'Tim Southee', 'Kasun Rajitha', 'Lahiru Kumara',
#        'Stephan Myburgh', 'Fakhar Zaman', 'Deepak Hooda',
#        'Bhuvneshwar Kumar', 'Mohammed Shami', 'Arshdeep Singh',
#        'Gulbadin Naib', 'Sam Curran', 'Mohammad Haris', 'Naseem Shah',
#        'Heinrich Klaasen', 'Kagiso Rabada', 'Anrich Nortje',
#        'Lungi Ngidi', 'Tabraiz Shamsi', 'Cameron Green', 'Steven Smith',
#        'Matthew Wade(c)â€\xa0', 'Kane Richardson', 'Darwish Rasooli',
#        'Naveen-ul-Haq', 'Chris Woakes', 'Keshav Maharaj', 'Nasum Ahmed',
#        'Rishabh Pantâ€\xa0', 'Wellington Masakadza', 'Phil Salt'],
#       dtype=object)

# %% [markdown]
# #### names contain "â€\xa0" this unknown characters and we need to remove them first

# %%
batting_summary['batsmanName'] = batting_summary['batsmanName'].apply(lambda x : x.replace("â€\xa0",""))

# %%
batting_summary['batsmanName'].unique()
# Out:
# array(['Michael van Lingen', 'Divan la Cock', 'Jan Nicol Loftie-Eaton',
#        'Stephan Baard', 'Gerhard Erasmus(c)', 'Jan Frylinck',
#        'David Wiese', 'JJ Smit', 'Pathum Nissanka', 'Kusal Mendis',
#        'Dhananjaya de Silva', 'Danushka Gunathilaka', 'Bhanuka Rajapaksa',
#        'Dasun Shanaka(c)', 'Wanindu Hasaranga de Silva',
#        'Chamika Karunaratne', 'Pramod Madushan', 'Dushmantha Chameera',
#        'Maheesh Theekshana', 'Chirag Suri', 'Muhammad Waseem',
#        'Kashif Daud', 'Vriitya Aravind', 'Zawar Farid', 'Basil Hameed',
#        'Chundangapoyil Rizwan(c)', 'Aayan Afzal Khan',
#        'Karthik Meiyappan', 'Junaid Siddique', 'Vikramjit Singh',
#        "Max O'Dowd", 'Bas de Leede', 'Colin Ackermann', 'Tom Cooper',
#        'Scott Edwards(c)', 'Roelof van der Merwe', 'Tim Pringle',
#        'Logan van Beek', 'George Munsey', 'Michael Jones',
#        'Matthew Cross', 'Richie Berrington(c)', 'Calum MacLeod',
#        'Michael Leask', 'Chris Greaves', 'Kyle Mayers', 'Evin Lewis',
#        'Brandon King', 'Nicholas Pooran(c)', 'Shamarh Brooks',
#        'Rovman Powell', 'Jason Holder', 'Akeal Hosein', 'Alzarri Joseph',
#        'Odean Smith', 'Obed McCoy', 'Regis Chakabva', 'Craig Ervine(c)',
#        'Wessly Madhevere', 'Sean Williams', 'Sikandar Raza',
#        'Milton Shumba', 'Ryan Burl', 'Luke Jongwe', 'Paul Stirling',
#        'Andy Balbirnie(c)', 'Lorcan Tucker', 'Harry Tector',
#        'Curtis Campher', 'George Dockrell', 'Gareth Delany', 'Mark Adair',
#        'Simi Singh', 'Barry McCarthy', 'Josh Little', 'Charith Asalanka',
#        'Aryan Lakra', 'Zahoor Khan', 'Johnson Charles',
#        'Regis Chakabva(c)', 'Tony Munyonga', 'Richard Ngarava',
#        'Tendai Chatara', 'Blessing Muzarabani', 'Timm van der Gugten',
#        'Fred Klaassen', 'Paul van Meekeren', 'Alishan Sharafu',
#        'Zane Green', 'Ruben Trumpelmann', 'Bernard Scholtz', 'Josh Davey',
#        'Finn Allen', 'Devon Conway', 'Kane Williamson(c)',
#        'Glenn Phillips', 'James Neesham', 'David Warner',
#        'Aaron Finch(c)', 'Mitchell Marsh', 'Glenn Maxwell',
#        'Marcus Stoinis', 'Tim David', 'Matthew Wade', 'Pat Cummins',
#        'Mitchell Starc', 'Adam Zampa', 'Josh Hazlewood',
#        'Hazratullah Zazai', 'Rahmanullah Gurbaz', 'Ibrahim Zadran',
#        'Usman Ghani', 'Najibullah Zadran', 'Mohammad Nabi(c)',
#        'Azmatullah Omarzai', 'Rashid Khan', 'Mujeeb Ur Rahman',
#        'Fareed Ahmad', 'Fazalhaq Farooqi', 'Jos Buttler(c)', 'Alex Hales',
#        'Dawid Malan', 'Ben Stokes', 'Liam Livingstone', 'Harry Brook',
#        'Moeen Ali', 'Mohammad Rizwan', 'Babar Azam(c)', 'Shan Masood',
#        'Iftikhar Ahmed', 'Shadab Khan', 'Haider Ali', 'Mohammad Nawaz',
#        'Asif Ali', 'Shaheen Shah Afridi', 'Haris Rauf', 'KL Rahul',
#        'Rohit Sharma(c)', 'Virat Kohli', 'Suryakumar Yadav', 'Axar Patel',
#        'Hardik Pandya', 'Dinesh Karthik', 'Ravichandran Ashwin',
#        'Najmul Hossain Shanto', 'Soumya Sarkar', 'Litton Das',
#        'Shakib Al Hasan(c)', 'Afif Hossain', 'Yasir Ali', 'Nurul Hasan',
#        'Mosaddek Hossain', 'Taskin Ahmed', 'Hasan Mahmud', 'Shariz Ahmad',
#        'Quinton de Kock', 'Temba Bavuma(c)', 'Fionn Hand',
#        'Rilee Rossouw', 'Tristan Stubbs', 'Aiden Markram', 'David Miller',
#        'Wayne Parnell', 'Mehidy Hasan Miraz', 'Mustafizur Rahman',
#        'Brad Evans', 'Mohammad Wasim', 'Daryl Mitchell',
#        'Mitchell Santner', 'Ish Sodhi', 'Tim Southee', 'Kasun Rajitha',
#        'Lahiru Kumara', 'Stephan Myburgh', 'Fakhar Zaman', 'Deepak Hooda',
#        'Bhuvneshwar Kumar', 'Mohammed Shami', 'Arshdeep Singh',
#        'Gulbadin Naib', 'Sam Curran', 'Mohammad Haris', 'Naseem Shah',
#        'Heinrich Klaasen', 'Kagiso Rabada', 'Anrich Nortje',
#        'Lungi Ngidi', 'Tabraiz Shamsi', 'Cameron Green', 'Steven Smith',
#        'Matthew Wade(c)', 'Kane Richardson', 'Darwish Rasooli',
#        'Naveen-ul-Haq', 'Chris Woakes', 'Keshav Maharaj', 'Nasum Ahmed',
#        'Rishabh Pant', 'Wellington Masakadza', 'Phil Salt'], dtype=object)

# %% [markdown]
# lets check for other names team names also is there any spelling errror or not

# %%
batting_summary['teamInnings'].unique()
# Out:
# array(['Namibia', 'Sri Lanka', 'U.A.E.', 'Netherlands', 'Scotland',
#        'West Indies', 'Zimbabwe', 'Ireland', 'New Zealand', 'Australia',
#        'Afghanistan', 'England', 'Pakistan', 'India', 'Bangladesh',
#        'South Africa'], dtype=object)

# %%
# it looks fine

# %% [markdown]
# ### mapping match details with match code also using above data of batting

# %%
batting_summary['match_code'] = batting_summary['match'].map(match_id_dicts)

# %%
batting_summary
# Out:
#                     match teamInnings  battingPos             batsmanName  \
# 0    Namibia Vs Sri Lanka     Namibia           1      Michael van Lingen
# 1    Namibia Vs Sri Lanka     Namibia           2           Divan la Cock
# 2    Namibia Vs Sri Lanka     Namibia           3  Jan Nicol Loftie-Eaton
# 3    Namibia Vs Sri Lanka     Namibia           4           Stephan Baard
# 4    Namibia Vs Sri Lanka     Namibia           5      Gerhard Erasmus(c)
# ..                    ...         ...         ...                     ...
# 694   Pakistan Vs England     England           3               Phil Salt
# 695   Pakistan Vs England     England           4              Ben Stokes
# 696   Pakistan Vs England     England           5             Harry Brook
# 697   Pakistan Vs England     England           6               Moeen Ali
# 698   Pakistan Vs England     England           7        Liam Livingstone
#
#     runs balls 4s 6s      SR out/notout   match_code
# 0      3     6  0  0   50.00        out  T20I # 1823
# 1      9     9  1  0  100.00        out  T20I # 1823
# 2     20    12  1  2  166.66        out  T20I # 1823
# 3     26    24  2  0  108.33        out  T20I # 1823
# 4     20    24  0  0   83.33        out  T20I # 1823
# ..   ...   ... .. ..     ...        ...          ...
# 694   10     9  2  0  111.11        out  T20I # 1879
# 695   52    49  5  1  106.12     notout  T20I # 1879
# 696   20    23  1  0   86.95        out  T20I # 1879
# 697   19    13  3  0  146.15        out  T20I # 1879
# 698    1     1  0  0  100.00     notout  T20I # 1879
#
# [699 rows x 11 columns]

# %%
batting_summary.to_csv('csv_files//batting_summary.csv')

# %% [markdown]
# ### Opening bowling data json file

# %%
with open ('t20_json_files//t20_wc_bowling_summary.json') as f:
    data = json.load(f)

# %%
data[1]
# Out:
# {'bowlingSummary': [{'match': 'U.A.E. Vs Netherlands',
#    'bowlingTeam': 'Netherlands',
#    'bowlerName': 'Fred Klaassen',
#    'overs': '4',
#    'maiden': '0',
#    'runs': '13',
#    'wickets': '2',
#    'economy': '3.25',
#    '0s': '18',
#    '4s': '0',
#    '6s': '0',
#    'wides': '3',
#    'noBalls': '0'},
#   {'match': 'U.A.E. Vs Netherlands',
#    'bowlingTeam': 'Netherlands',
#    'bowlerName': 'Tim Pringle',
#    'overs': '4',
#    'maiden': '0',
#    'runs': '13',
#    'wickets': '1',
#    'economy': '3.25',
#    '0s': '11',
#    '4s': '0',
#    '6s': '0',
#    'wides': '0',
#    'noBalls': '0'},
#   {'match': 'U.A.E. Vs Netherlands',
#    'bowlingTeam': 'Netherlands',
#    'bowlerName': 'Logan van Beek',
#    'overs': '2',
#    'maiden': '0',
#    'runs': '19',
#    'wickets': '0',
#    'economy': '9.50',
#    '0s': '5',
#    '4s': '0',
#    '6s': '2',
#    'wides': '1',
#    'noBalls': '0'},
#   {'match': 'U.A.E. Vs Netherlands',
#    'bowlingTeam': 'Netherlands',
#    'bowlerName': 'Bas de Leede',
#    'overs': '3',
#    'maiden': '0',
#    'runs': '19',
#    'wickets': '3',
#    'economy': '6.33',
#    '0s': '9',
#    '4s': '2',
#    '6s': '0',
#    'wides': '2',
#    'noBalls': '0'},
#   {'match': 'U.A.E. Vs Netherlands',
#    'bowlingTeam': 'Netherlands',
#    'bowlerName': 'Paul van Meekeren',
#    'overs': '4',
#    'maiden': '0',
#    'runs': '21',
#    'wickets': '0',
#    'economy': '5.25',
#    '0s': '11',
#    '4s': '1',
#    '6s': '0',
#    'wides': '0',
#    'noBalls': '0'},
#   {'match': 'U.A.E. Vs Netherlands',
#    'bowlingTeam': 'Netherlands',
#    'bowlerName': 'Roelof van der Merwe',
#    'overs': '3',
#    'maiden': '0',
#    'runs': '19',
#    'wickets': '1',
#    'economy': '6.33',
#    '0s': '7',
#    '4s': '0',
#    '6s': '1',
#    'wides': '0',
#    'noBalls': '0'},
#   {'match': 'U.A.E. Vs Netherlands',
#    'bowlingTeam': 'U.A.E.',
#    'bowlerName': 'Junaid Siddique',
#    'overs': '4',
#    'maiden': '0',
#    'runs': '24',
#    'wickets': '3',
#    'economy': '6.00',
#    '0s': '10',
#    '4s': '2',
#    '6s': '0',
#    'wides': '1',
#    'noBalls': '0'},
#   {'match': 'U.A.E. Vs Netherlands',
#    'bowlingTeam': 'U.A.E.',
#    'bowlerName': 'Basil Hameed',
#    'overs': '1',
#    'maiden': '0',
#    'runs': '7',
#    'wickets': '1',
#    'economy': '7.00',
#    '0s': '4',
#    '4s': '0',
#    '6s': '1',
#    'wides': '0',
#    'noBalls': '0'},
#   {'match': 'U.A.E. Vs Netherlands',
#    'bowlingTeam': 'U.A.E.',
#    'bowlerName': 'Aayan Afzal Khan',
#    'overs': '3',
#    'maiden': '0',
#    'runs': '15',
#    'wickets': '1',
#    'economy': '5.00',
#    '0s': '8',
#    '4s': '1',
#    '6s': '0',
#    'wides': '0',
#    'noBalls': '0'},
#   {'match': 'U.A.E. Vs Netherlands',
#    'bowlingTeam': 'U.A.E.',
#    'bowlerName': 'Karthik Meiyappan',
#    'overs': '4',
#    'maiden': '0',
#    'runs': '22',
#    'wickets': '1',
#    'economy': '5.50',
#    '0s': '11',
#    '4s': '2',
#    '6s': '0',
#    'wides': '0',
#    'noBalls': '0'},
#   {'match': 'U.A.E. Vs Netherlands',
#    'bowlingTeam': 'U.A.E.',
#    'bowlerName': 'Zahoor Khan',
#    'overs': '4',
#    'maiden': '0',
#    'runs': '11',
#    'wickets': '1',
#    'economy': '2.75',
#    '0s': '14',
#    '4s': '0',
#    '6s': '0',
#    'wides': '0',
#    'noBalls': '0'},
#   {'match': 'U.A.E. Vs Netherlands',
#    'bowlingTeam': 'U.A.E.',
#    'bowlerName': 'Zawar Farid',
#    'overs': '2.5',
#    'maiden': '0',
#    'runs': '24',
#    'wickets': '0',
#    'economy': '8.47',
#    '0s': '2',
#    '4s': '2',
#    '6s': '0',
#    'wides': '0',
#    'noBalls': '0'},
#   {'match': 'U.A.E. Vs Netherlands',
#    'bowlingTeam': 'U.A.E.',
#    'bowlerName': 'Kashif Daud',
#    'overs': '1',
#    'maiden': '0',
#    'runs': '5',
#    'wickets': '0',
#    'economy': '5.00',
#    '0s': '1',
#    '4s': '0',
#    '6s': '0',
#    'wides': '0',
#    'noBalls': '0'}]}

# %%
arr = []
for i in range(len(data)):
    for j in range(len(data[i]['bowlingSummary'])):
        arr.append(data[i]['bowlingSummary'][j])

# %%
len(arr)
# Out:
# 500

# %%
bowling_summary = pd.DataFrame(arr)

# %%
bowling_summary
# Out:
#                     match bowlingTeam                  bowlerName overs  \
# 0    Namibia Vs Sri Lanka   Sri Lanka          Maheesh Theekshana     4
# 1    Namibia Vs Sri Lanka   Sri Lanka         Dushmantha Chameera     4
# 2    Namibia Vs Sri Lanka   Sri Lanka             Pramod Madushan     4
# 3    Namibia Vs Sri Lanka   Sri Lanka         Chamika Karunaratne     4
# 4    Namibia Vs Sri Lanka   Sri Lanka  Wanindu Hasaranga de Silva     4
# ..                    ...         ...                         ...   ...
# 495   Pakistan Vs England    Pakistan                 Naseem Shah     4
# 496   Pakistan Vs England    Pakistan                  Haris Rauf     4
# 497   Pakistan Vs England    Pakistan                 Shadab Khan     4
# 498   Pakistan Vs England    Pakistan              Mohammad Wasim     4
# 499   Pakistan Vs England    Pakistan              Iftikhar Ahmed   0.5
#
#     maiden runs wickets economy  0s 4s 6s wides noBalls
# 0        0   23       1    5.75   7  0  0     2       0
# 1        0   39       1    9.75   6  3  1     2       0
# 2        0   37       2    9.25   6  3  1     0       0
# 3        0   36       1    9.00   7  3  1     1       0
# 4        0   27       1    6.75   8  1  1     0       0
# ..     ...  ...     ...     ...  .. .. ..   ...     ...
# 495      0   30       0    7.50  15  3  1     1       0
# 496      0   23       2    5.75  13  3  0     1       0
# 497      0   20       1    5.00  10  1  0     0       0
# 498      0   38       1    9.50   5  5  0     2       0
# 499      0   13       0   15.60   0  1  1     0       0
#
# [500 rows x 13 columns]

# %% [markdown]
# lets check for names again here

# %%
bowling_summary['bowlerName'].unique()
# Out:
# array(['Maheesh Theekshana', 'Dushmantha Chameera', 'Pramod Madushan',
#        'Chamika Karunaratne', 'Wanindu Hasaranga de Silva',
#        'Gerhard Erasmus', 'David Wiese', 'Bernard Scholtz',
#        'Ben Shikongo', 'JJ Smit', 'Jan Frylinck', 'Fred Klaassen',
#        'Tim Pringle', 'Logan van Beek', 'Bas de Leede',
#        'Paul van Meekeren', 'Roelof van der Merwe', 'Junaid Siddique',
#        'Basil Hameed', 'Aayan Afzal Khan', 'Karthik Meiyappan',
#        'Zahoor Khan', 'Zawar Farid', 'Kashif Daud', 'Kyle Mayers',
#        'Akeal Hosein', 'Alzarri Joseph', 'Obed McCoy', 'Jason Holder',
#        'Odean Smith', 'Mark Watt', 'Brad Wheal', 'Josh Davey',
#        'Safyaan Sharif', 'Michael Leask', 'Josh Little', 'Mark Adair',
#        'Barry McCarthy', 'Curtis Campher', 'Simi Singh', 'Gareth Delany',
#        'Richard Ngarava', 'Tendai Chatara', 'Blessing Muzarabani',
#        'Luke Jongwe', 'Sean Williams', 'Sikandar Raza', 'Colin Ackermann',
#        'Timm van der Gugten', 'Jan Nicol Loftie-Eaton', 'Aryan Lakra',
#        'Dasun Shanaka', 'George Dockrell', 'Chris Greaves', 'Ryan Burl',
#        'Dhananjaya de Silva', 'Lahiru Kumara', 'Binura Fernando',
#        'Ruben Trumpelmann', 'Ahmed Raza', 'Muhammad Waseem',
#        'Wessly Madhevere', 'Calum MacLeod', 'Mitchell Starc',
#        'Josh Hazlewood', 'Pat Cummins', 'Marcus Stoinis', 'Adam Zampa',
#        'Trent Boult', 'Tim Southee', 'Mitchell Santner',
#        'Lockie Ferguson', 'Ish Sodhi', 'Ben Stokes', 'Chris Woakes',
#        'Mark Wood', 'Sam Curran', 'Adil Rashid', 'Fazalhaq Farooqi',
#        'Azmatullah Omarzai', 'Mujeeb Ur Rahman', 'Rashid Khan',
#        'Fareed Ahmad', 'Mohammad Nabi', 'Bhuvneshwar Kumar',
#        'Arshdeep Singh', 'Mohammed Shami', 'Hardik Pandya',
#        'Ravichandran Ashwin', 'Axar Patel', 'Shaheen Shah Afridi',
#        'Naseem Shah', 'Haris Rauf', 'Shadab Khan', 'Mohammad Nawaz',
#        'Shariz Ahmad', 'Taskin Ahmed', 'Hasan Mahmud', 'Shakib Al Hasan',
#        'Mustafizur Rahman', 'Soumya Sarkar', 'Mosaddek Hossain',
#        'Kagiso Rabada', 'Wayne Parnell', 'Lungi Ngidi', 'Keshav Maharaj',
#        'Anrich Nortje', 'Ashton Agar', 'Mitchell Marsh', 'Glenn Maxwell',
#        'Liam Livingstone', 'Fionn Hand', 'Mehidy Hasan Miraz',
#        'Afif Hossain', 'Tabraiz Shamsi', 'Mohammad Wasim', 'Brad Evans',
#        'Kasun Rajitha', 'Brandon Glover', 'Aiden Markram',
#        'Gulbadin Naib', 'Moeen Ali', 'Shoriful Islam', 'Naveen-ul-Haq',
#        'Kane Richardson', 'Cameron Green', 'Charith Asalanka',
#        'Iftikhar Ahmed', 'Nasum Ahmed', 'Ebadot Hossain',
#        'Wellington Masakadza', 'Chris Jordan'], dtype=object)

# %%
# its clean

# %% [markdown]
# ### here also we will map details with team code

# %%
bowling_summary['match_code'] = bowling_summary['match'].map(match_id_dicts)

# %%
bowling_summary
# Out:
#                     match bowlingTeam                  bowlerName overs  \
# 0    Namibia Vs Sri Lanka   Sri Lanka          Maheesh Theekshana     4
# 1    Namibia Vs Sri Lanka   Sri Lanka         Dushmantha Chameera     4
# 2    Namibia Vs Sri Lanka   Sri Lanka             Pramod Madushan     4
# 3    Namibia Vs Sri Lanka   Sri Lanka         Chamika Karunaratne     4
# 4    Namibia Vs Sri Lanka   Sri Lanka  Wanindu Hasaranga de Silva     4
# ..                    ...         ...                         ...   ...
# 495   Pakistan Vs England    Pakistan                 Naseem Shah     4
# 496   Pakistan Vs England    Pakistan                  Haris Rauf     4
# 497   Pakistan Vs England    Pakistan                 Shadab Khan     4
# 498   Pakistan Vs England    Pakistan              Mohammad Wasim     4
# 499   Pakistan Vs England    Pakistan              Iftikhar Ahmed   0.5
#
#     maiden runs wickets economy  0s 4s 6s wides noBalls   match_code
# 0        0   23       1    5.75   7  0  0     2       0  T20I # 1823
# 1        0   39       1    9.75   6  3  1     2       0  T20I # 1823
# 2        0   37       2    9.25   6  3  1     0       0  T20I # 1823
# 3        0   36       1    9.00   7  3  1     1       0  T20I # 1823
# 4        0   27       1    6.75   8  1  1     0       0  T20I # 1823
# ..     ...  ...     ...     ...  .. .. ..   ...     ...          ...
# 495      0   30       0    7.50  15  3  1     1       0  T20I # 1879
# 496      0   23       2    5.75  13  3  0     1       0  T20I # 1879
# 497      0   20       1    5.00  10  1  0     0       0  T20I # 1879
# 498      0   38       1    9.50   5  5  0     2       0  T20I # 1879
# 499      0   13       0   15.60   0  1  1     0       0  T20I # 1879
#
# [500 rows x 14 columns]

# %%
bowling_summary.to_csv('csv_files//bowling_summary.csv')

# %% [markdown]
# ## Now we will import those csv files into Power BI and if some transformation required we can do it in Power Query.
